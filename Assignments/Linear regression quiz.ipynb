# %%
import pandas as pd

# %%
import numpy as np

# %%
data1 = pd.read_csv("data.csv")

# %%
data1.head(5)
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
x = data1[['YearsExperience']]

# %%
y = data1[['Salary']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
salarymodel = LinearRegression()

# %%
salarymodel.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
prediction = salarymodel.predict(x_test)

# %%
x_test
# Out:
#     YearsExperience
# 27              9.6
# 15              4.9
# 23              8.2
# 17              5.3
# 8               3.2
# 9               3.7
# 28             10.3
# 24              8.7
# 12              4.0
# 0               1.1
# 4               2.2
# 16              5.1

# %%
prediction
# Out:
# array([[115941.4335911 ],
#        [ 72302.50533756],
#        [102942.60389856],
#        [ 76016.45667829],
#        [ 56518.21213947],
#        [ 61160.65131538],
#        [122440.84843738],
#        [107585.04307447],
#        [ 63946.11482092],
#        [ 37019.96760065],
#        [ 47233.33378765],
#        [ 74159.48100792]])

# %%
mse = mean_squared_error(y_test, prediction )
r2 = r2_score(y_test, prediction)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 37867393.38893943
# R-squared: 0.9532338376280692

# %%
plt.scatter(x_test, y_test, color='blue')
plt.plot(x_test, prediction, color='red', linewidth=2)
plt.title('Actual vs. Predicted Salary')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

# %%
data2 = pd.read_csv("housing.csv")

# %%
data2.head(5)
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
data2.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
null_values = data2.isnull().sum()
print(null_values)
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
import seaborn as sns

# %%
plt.figure(figsize=(12, 6))
sns.scatterplot(x='sqft_living', y='price', data=data2)
plt.title('Price vs Sqft Living')
plt.xlabel('Sqft Living')
plt.ylabel('Price')
plt.show()

# %%
numeric_data = data2.select_dtypes(include=np.number)

# %%
# Out:
#                id   price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0      7129300520  221900         3       1.00         1180      5650     1.0
# 1      6414100192  538000         3       2.25         2570      7242     2.0
# 2      5631500400  180000         2       1.00          770     10000     1.0
# 3      2487200875  604000         4       3.00         1960      5000     1.0
# 4      1954400510  510000         3       2.00         1680      8080     1.0
# ...           ...     ...       ...        ...          ...       ...     ...
# 21608   263000018  360000         3       2.50         1530      1131     3.0
# 21609  6600060120  400000         4       2.50         2310      5813     2.0
# 21610  1523300141  402101         2       0.75         1020      1350     2.0
# 21611   291310100  400000         3       2.50         1600      2388     2.0
# 21612  1523300157  325000         2       0.75         1020      1076     2.0
#
# ...

# %%
data2['date'] = data2['date'].astype(str)

# %%
data2['date'] = data2['date'].str.replace('T000000', '')

# %%
data2['date'] = pd.to_datetime(data2['date'], format='%Y%m%d')

# %%
data2
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520 2014-10-13  221900         3       1.00         1180
# 1      6414100192 2014-12-09  538000         3       2.25         2570
# 2      5631500400 2015-02-25  180000         2       1.00          770
# 3      2487200875 2014-12-09  604000         4       3.00         1960
# 4      1954400510 2015-02-18  510000         3       2.00         1680
# ...           ...        ...     ...       ...        ...          ...
# 21608   263000018 2014-05-21  360000         3       2.50         1530
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
correlation_matrix = data2.corr()
plt.figure(figsize=(12, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %%
x = data2[['sqft_living']]

# %%
y = data2['price']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
house_model = LinearRegression()

# %%
house_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = house_model.predict(x_test)

# %%
y_pred
# Out:
# array([ 536638.48784377,  768631.88324074, 1011805.68323515, ...,
#         279489.18210255,  556204.1958893 ,  659622.93841566])

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print("Mean Squared Error:", mse)
print("R-squared:", r2)
# Out:
# Mean Squared Error: 74509995148.44868
# R-squared: 0.48388318901296545

# %%
plt.figure(figsize=(12, 6))
plt.scatter(x_test, y_test, color='blue')
plt.plot(x_test, y_pred, color='red', linewidth=3)
plt.title('Linear Regression: Price vs Sqft Living')
plt.xlabel('Sqft Living')
plt.ylabel('Price')
plt.show()

# %%
# Assuming 'data' is your DataFrame containing the employee data
# Filter the dataset based on the conditions
filtered_data1 = data1[(data1['Salary'] >=50000) & (data1['Salary'] <= 60000)]

# Count the number of rows in the filtered dataset
num_employees2 = len(filtered_data1)

# Print the result
print("Number of employees with more than 5 years of experience earning more than $60,000:", num_employees2)
# Out:
# Number of employees with more than 5 years of experience earning more than $60,000: 6

# %%
filtered_data2 = data2[data2['floors'] ==2]

# %%
filtered_data2
# Out:
#                id       date   price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192 2014-12-09  538000         3       2.25         2570
# 6      1321400060 2014-06-27  257500         3       2.25         1715
# 9      3793500160 2015-03-12  323000         3       2.50         1890
# 15     9297300055 2015-01-24  650000         4       3.00         2950
# 16     1875500060 2014-07-31  395000         3       2.00         1890
# ...           ...        ...     ...       ...        ...          ...
# 21607  2997800021 2015-02-19  475000         3       2.50         1310
# 21609  6600060120 2015-02-23  400000         4       2.50         2310
# 21610  1523300141 2014-06-23  402101         2       0.75         1020
# 21611   291310100 2015-01-16  400000         3       2.50         1600
# 21612  1523300157 2014-10-15  325000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# ...

# %%
filtered_data3 = data2[(data2['date'] < '1960-01-01') & (data2['waterfront'] == 1)]

# %%
filtered_data3
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
filtered_data4 = data2[data2['bathrooms'] > 4]

# %%
filtered_data5 =  filtered_data4['price'].max()

# %%
filtered_data5
# Out:
# 7700000
